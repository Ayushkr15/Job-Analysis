# %% [markdown]
# Preprocessing Steps

# %%
import pandas as pd

# %%
df = pd.read_csv("jobs_data.csv")
df.head()
# Out:
#                    jobTitle                                company  \
# 0              Data Analyst                              Version 1
# 1              Data Analyst  Wolters Kluwer - Medknow Publications
# 2              Data Analyst                               Indegene
# 3              Data Analyst                             Klene Paks
# 4  Team Member Data Analyst        Bajaj Allianz General Insurance
#
#                        location experience          salary  \
# 0                     Bengaluru    0-3 Yrs   Not disclosed
# 1                 Kalyani, Pune    3-5 Yrs   Not disclosed
# 2                     Bengaluru    0-4 Yrs   Not disclosed
# 3  Bengaluru(Bannerghatta Road)    3-8 Yrs  3.75-6 Lacs PA
# 4                          Pune    0-4 Yrs   Not disclosed
#
#                                              jobLink  \
# 0  https://www.naukri.com/job-listings-data-analy...
# 1  https://www.naukri.com/job-listings-data-analy...
# 2  https://www.naukri.com/job-listings-data-analy...
# 3  https://www.naukri.com/job-listings-data-analy...
# 4  https://www.naukri.com/job-listings-team-membe...
#
#                                               skills
# 0  Computer science, Data analysis, Analytical, A...
# 1  Computer science, Backend, Data analysis, Data...
# 2  Automation, Data analysis, Business analytics,...
# 3  HLOOKUP, Pivot Table, VLOOKUP, Excel Macros, D...
# 4  Automation, Data validation, Process efficienc...

# %%
df.dtypes
# Out:
# jobTitle      object
# company       object
# location      object
# experience    object
# salary        object
# jobLink       object
# skills        object
# dtype: object

# %%
# Converting experience to numbers
def exp_min_max(exp):
    if pd.isna(exp) or 'N/A' in exp:
        return None , None
    if 'Yrs' in exp:
        exp = exp.replace('Yrs' , '')
        if '-' in exp:
            min_exp , max_exp = map(int , exp.split('-'))
            return min_exp , max_exp
        else:
            return int(exp), int(exp)
    return None, None

df[['experience_min' , 'experience_max']] = df['experience'].apply(lambda x:pd.Series(exp_min_max(x)))
print("Done")
# Out:
# Done

# %%
# Removing Experience Column
df.drop('experience' , axis = 1, inplace = True)

# %%
# Finding all the missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# jobTitle           0
# company            0
# location           5
# salary             0
# jobLink            0
# skills             9
# experience_min    14
# experience_max    14
# dtype: int64

# %%
# Droping all the rows which have nan values
df.dropna(inplace=True)

# %%
# Again checking for Missing Values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# jobTitle          0
# company           0
# location          0
# salary            0
# jobLink           0
# skills            0
# experience_min    0
# experience_max    0
# dtype: int64

# %%
# Changin Datatype of minimum and maximum experience
df['experience_min'] = df['experience_min'].astype(int)
df['experience_max'] = df['experience_max'].astype(int)

# %%
import re

# Function to process salary data
def salary(sal):
    # Handle 'Not disclosed' case
    if 'Not disclosed' in sal:
        return None, None  # Return None for missing salary data
    
    # Remove unwanted characters using regular expressions
    sal = re.sub(r'[^0-9.-]', '', sal)  # Keep only numbers, periods, and hyphens

    # Process salary range or single salary
    if '-' in sal:  # If salary is a range (e.g., '3.75-6')
        try:
            # Split the range and convert to float
            min_salary, max_salary = map(float, sal.split('-'))  
            return min_salary, max_salary
        except ValueError:
            print(f"Error processing range: {sal}")  # Print error if parsing fails
            return None, None
    else:  # If it's a single salary value (e.g., '5')
        try:
            salary_value = float(sal)  # Convert to float for single salary
            return salary_value, salary_value
        except ValueError:
            print(f"Error processing single salary: {sal}")  # Print error if parsing fails
            return None, None
    return None, None  # Return None if the salary format is unexpected

df[['min_salary', 'max_salary']] = df['salary'].apply(lambda x: pd.Series(salary(x)))

# Display the DataFrame with processed salary column
print(df[['salary', 'min_salary', 'max_salary']].head(20))
# Out:
#               salary  min_salary  max_salary
# 0      Not disclosed         NaN         NaN
# 1      Not disclosed         NaN         NaN
# 2      Not disclosed         NaN         NaN
# 3     3.75-6 Lacs PA        3.75         6.0
# 4      Not disclosed         NaN         NaN
# 5      Not disclosed         NaN         NaN
# 6      Not disclosed         NaN         NaN
# 7      Not disclosed         NaN         NaN
# 8      Not disclosed         NaN         NaN
# 9       8-16 Lacs PA        8.00        16.0
# 10     Not disclosed         NaN         NaN
# 11     Not disclosed         NaN         NaN
# 12     Not disclosed         NaN         NaN
# 13     Not disclosed         NaN         NaN
# 14     Not disclosed         NaN         NaN
# 15     Not disclosed         NaN         NaN
# 16     Not disclosed         NaN         NaN
# 17     Not disclosed         NaN         NaN
# 18  1.44-1.8 Lacs PA        1.44         1.8
# 19     Not disclosed         NaN         NaN

# %%
df.drop('salary' , axis = 1, inplace=True)

# %%
df.head(10)
# Out:
#                                    jobTitle  \
# 0                              Data Analyst
# 1                              Data Analyst
# 2                              Data Analyst
# 3                              Data Analyst
# 4                  Team Member Data Analyst
# 5                        Cloud Data Analyst
# 6           ESG Data Analyst - ESG Newsroom
# 7           ESG Data Analyst : ESG Newsroom
# 8           ESG Data Analyst : ESG Newsroom
# 9  Openings For Data Analyst with Relevantz
#
#                                  company                      location  \
# 0                              Version 1                     Bengaluru
# 1  Wolters Kluwer - Medknow Publications                 Kalyani, Pune
# 2                               Indegene                     Bengaluru
# 3                             Klene Paks  Bengaluru(Bannerghatta Road)
# 4        Bajaj Allianz General Insurance                          Pune
# 5                                    IBM                     Bengaluru
# 6     Institutional Shareholder Services                        Mumbai
# 7                ISS Corporate Solutions                        Mumbai
# 8             Social Corporate Solutions                        Mumbai
# 9          Relevantz Technology Services                       Chennai
#
#                                              jobLink  \
# 0  https://www.naukri.com/job-listings-data-analy...
# 1  https://www.naukri.com/job-listings-data-analy...
# 2  https://www.naukri.com/job-listings-data-analy...
# 3  https://www.naukri.com/job-listings-data-analy...
# 4  https://www.naukri.com/job-listings-team-membe...
# 5  https://www.naukri.com/job-listings-cloud-data...
# 6  https://www.naukri.com/job-listings-esg-data-a...
# 7  https://www.naukri.com/job-listings-esg-data-a...
# 8  https://www.naukri.com/job-listings-esg-data-a...
# 9  https://www.naukri.com/job-listings-openings-f...
#
#                                               skills  experience_min  \
# 0  Computer science, Data analysis, Analytical, A...               0
# 1  Computer science, Backend, Data analysis, Data...               3
# 2  Automation, Data analysis, Business analytics,...               0
# 3  HLOOKUP, Pivot Table, VLOOKUP, Excel Macros, D...               3
# 4  Automation, Data validation, Process efficienc...               0
# 5  python, data analytics, consumables, team lead...               5
# 6  Environmental science, Corporate governance, B...               0
# 7  Environmental science, Corporate governance, B...               0
# 8  Environmental science, Corporate governance, B...               0
# 9  Data analyst, Banking Sector, Data Warehousing...               5
#
#    experience_max  min_salary  max_salary
# 0               3         NaN         NaN
# 1               5         NaN         NaN
# 2               4         NaN         NaN
# 3               8        3.75         6.0
# 4               4         NaN         NaN
# 5              10         NaN         NaN
# 6               3         NaN         NaN
# 7               3         NaN         NaN
# 8               3         NaN         NaN
# 9              10        8.00        16.0

# %%
df.to_csv('processed_DataSet.csv' , index = False)

# %%
df.head()
# Out:
#                    jobTitle                                company  \
# 0              Data Analyst                              Version 1
# 1              Data Analyst  Wolters Kluwer - Medknow Publications
# 2              Data Analyst                               Indegene
# 3              Data Analyst                             Klene Paks
# 4  Team Member Data Analyst        Bajaj Allianz General Insurance
#
#                        location  \
# 0                     Bengaluru
# 1                 Kalyani, Pune
# 2                     Bengaluru
# 3  Bengaluru(Bannerghatta Road)
# 4                          Pune
#
#                                              jobLink  \
# 0  https://www.naukri.com/job-listings-data-analy...
# 1  https://www.naukri.com/job-listings-data-analy...
# 2  https://www.naukri.com/job-listings-data-analy...
# 3  https://www.naukri.com/job-listings-data-analy...
# 4  https://www.naukri.com/job-listings-team-membe...
#
#                                               skills  experience_min  \
# 0  Computer science, Data analysis, Analytical, A...               0
# 1  Computer science, Backend, Data analysis, Data...               3
# 2  Automation, Data analysis, Business analytics,...               0
# 3  HLOOKUP, Pivot Table, VLOOKUP, Excel Macros, D...               3
# 4  Automation, Data validation, Process efficienc...               0
#
#    experience_max  min_salary  max_salary
# 0               3         NaN         NaN
# 1               5         NaN         NaN
# 2               4         NaN         NaN
# 3               8        3.75         6.0
# 4               4         NaN         NaN
